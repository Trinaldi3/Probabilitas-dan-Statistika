# %% [markdown]
# <a href="https://colab.research.google.com/github/Trinaldi3/Probabilitas-dan-Statistika/blob/main/ProbabilitasStatistika.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1: Import library
import pandas as pd
import matplotlib.pyplot as plt

# : Upload file excel ke Colab
from google.colab import files
uploaded = files.upload()

# 3: Baca data excel
import pandas as pd
path = "naldi.xlsx"
dataraw = pd.read_excel(path)
print(dataraw)
# Out:
#      <input type="file" id="files-699159b8-1abd-4152-820a-cc67ff476fc9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-699159b8-1abd-4152-820a-cc67ff476fc9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# 4: Tabel Frekuensi Grade
import pandas as pd
datafrq = pd.crosstab(index=dataraw["Grade"], columns="Frekuensi")
print(datafrq)
# Out:
# col_0  Frekuensi
# Grade
# A             12
# AB             7
# B              5
# BC             1
# C              5
# F              1

# %%
# 5: Grafik Garis
import matplotlib.pyplot as plt
datafrq.plot(color="darkorange", marker="o", linewidth=2)
plt.title("Grafik Garis Frekuensi Grade - Tri Naldi Syaputra Siregar")
plt.xlabel("Grade")
plt.ylabel("Jumlah Mahasiswa")
plt.grid(alpha=0.3)
plt.show()

# %%
# 6: Grafik Batang
import matplotlib.pyplot as plt
datafrq.plot(kind='bar', color="teal")
plt.title("Grafik Batang Frekuensi Grade - Tri Naldi Syaputra Siregar")
plt.xlabel("Grade")
plt.ylabel("Jumlah Mahasiswa")
plt.xticks(rotation=0)
plt.show()

# %%
# 7: Pie Chart
import matplotlib.pyplot as plt
datafrq.plot(
    kind='pie',
    y='Frekuensi',
    autopct='%1.0f%%',
    legend=False,
    colors=["#4C72B0", "#DD8452", "#55A868", "#C44E52", "#8172B2", "#937860"],
)
plt.title("Persentase Grade - Tri Naldi Syaputra Siregar")
plt.ylabel("")
plt.show()

# %%
# 8: Statistika Deskriptif
import pandas as pd
dataraw["Nilai"] = pd.to_numeric(dataraw["Nilai"], errors='coerce')
dt = dataraw["Nilai"]
stats = dt.describe()
stats['Standard Error'] = dt.sem()
stats['Median'] = dt.median()
stats['Mode'] = dt.mode().iloc[0]
stats['variance'] = dt.var()
stats['range'] = dt.max() - dt.min()
stats['skewness'] = dt.skew()
stats['kurtosis'] = dt.kurtosis()
print(stats)

# (tambahan): Kuartil & deteksi outlier dengan IQR
Q1 = dt.quantile(0.25)
Q3 = dt.quantile(0.75)
IQR = Q3 - Q1
batas_bawah = Q1 - 1.5 * IQR
batas_atas = Q3 + 1.5 * IQR
outlier = dt[(dt < batas_bawah) | (dt > batas_atas)]
print("Q1 =", Q1, " Q3 =", Q3, " IQR =", IQR)
print("Batas bawah =", batas_bawah, " Batas atas =", batas_atas)
print("Outlier ditemukan:", outlier.tolist())
# Out:
# count              31.000000
# mean               75.914194
# std                13.350219
# min                46.010000
# 25%                67.045000
# 50%                78.300000
# 75%                86.790000
# max                94.030000
# Standard Error      2.397770
# Median             78.300000
# Mode               77.300000
# variance          178.228338
# range              48.020000
# skewness           -0.596606
# kurtosis           -0.588483
# Name: Nilai, dtype: float64
# Q1 = 67.045  Q3 = 86.78999999999999  IQR = 19.74499999999999
# Batas bawah = 37.427500000000016  Batas atas = 116.40749999999997
# Outlier ditemukan: []
